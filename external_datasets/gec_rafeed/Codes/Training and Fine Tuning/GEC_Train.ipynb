# %%
# !pip install happytransformer

# %%
from happytransformer import HappyTextToText
from happytransformer import TTSettings
from happytransformer import TTTrainArgs
import pandas as pd
import torch

# %%
T5 = HappyTextToText("T5", "t5-small")

# %%
C4 = '/content/drive/MyDrive/Google Colab/Advanced NLP Project/Datasets/Parallel_C4.csv'
modelPath = '/content/drive/MyDrive/Google Colab/Advanced NLP/GEC_C4_model/'
T5 = HappyTextToText(load_path=modelPath) # use this for loading the trained model for further training if needed

for epoch in range(2):
    print(f'Epoch: {epoch}')
    args = TTTrainArgs(batch_size=16, learning_rate=0.0001, num_train_epochs=1, max_input_length=256, max_output_length=256)
    T5.train(C4, args=args)
    T5.save(modelPath)
# Out:
# 04/03/2022 08:10:44 - INFO - happytransformer.happy_transformer -   Using model: cuda
# 04/03/2022 08:10:54 - INFO - happytransformer.happy_transformer -   Preprocessing training data...
# Epoch: 0
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-05aa0f003212f283/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519. Subsequent calls will reuse this data.
# ...
#   0%|          | 0/717 [00:00<?, ?ba/s]
# 04/03/2022 08:12:35 - INFO - happytransformer.happy_transformer -   Training...
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 716837
#   Num Epochs = 1
# ...

# %%
modelPath = '/content/drive/MyDrive/Google Colab/Advanced NLP/GEC_C4_lang8_model/'
T5.save(modelPath)
